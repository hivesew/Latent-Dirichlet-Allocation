# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Load the cleaned course catalog
data = pd.read_csv('./cleaned_catalog.csv')  # Ensure this path matches your cleaned catalog file

# Function to display the top words for each topic
def display_topics(model, feature_names, no_top_words, subject):
    print(f"Subject: {subject}")
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
    print("\n")  # Print a newline for readability between subjects

no_top_words = 10

# Loop through each unique subject in the DataFrame
for subject in data['Subject'].unique():
    # Filter the DataFrame to only include courses for the current subject
    subject_data = data[data['Subject'] == subject]
    
    # Ensure there's enough data to perform LDA
    if subject_data.shape[0] < 5:  # Adjust this threshold as necessary
        print(f"Not enough data for subject: {subject}")
        continue

    # Vectorization - CountVectorizer
    vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
    dtm = vectorizer.fit_transform(subject_data['Description'])  # Adjust column name if different

    # LDA Model Training
    num_topics = 1
    lda = LatentDirichletAllocation(num_topics, random_state=0)  # Adjust n_components as necessary
    lda.fit(dtm)

    # Displaying Topics
    display_topics(lda, vectorizer.get_feature_names_out(), no_top_words, subject)
# Out:
# Not enough data for subject: AAS
# Subject: ABE
# Topic 1:
# design engineering water soil principles infrastructure food properties biological development
#
#
# Subject: ACCY
# Topic 1:
# accounting professional financial data business tax accountancy reporting complete information
#
#
# Subject: ACE
# Topic 1:
# financial agricultural planning food problems economic analysis data management economics
#
#
# Subject: ACES
# Topic 1:
# study abroad experience agricultural environmental sciences consumer academic special andor
#
#
# Subject: ADV
# Topic 1:
# advertising media research social consumer sales relations brand industry data
#
#
# Subject: AE
# Topic 1:
# aerospace engineering design control performance systems techniques registration waves theory
#
#
# Subject: AFAS
# Topic 1:
# leadership force cadets air designed afrotc skills seniors overview level
#
#
# Subject: AFRO
# Topic 1:
# african american hiphop political americans music studies study specifically understand
#
#
# Subject: AFST
# Topic 1:
# african studies supervised research
#
#
# Subject: AGCM
# Topic 1:
# science agricultural skills communication communications audiences broad campaigns writing information
#
#
# Subject: AGED
# Topic 1:
# learning education teaching programs field experience plans observation early development
#
#
# Not enough data for subject: AHS
# Subject: AIS
# Topic 1:
# american indian indigenous subsequent studies interdisciplinary tribal theories stories special
#
#
# Subject: ALEC
# Topic 1:
# learning training theories adult motivation concepts contexts covers professional agricultural
#
#
# Subject: ANSC
# Topic 1:
# animal animals production nutrition principles management issues sciences selection genetics
#
#
# Subject: ANTH
# Topic 1:
# research anthropology food human analysis social study language cultural field
#
#
# Subject: ARAB
# Topic 1:
# continuation literary language
#
#
# Subject: ARCH
# Topic 1:
# design architecture professional architectural buildings research separate systems building study
#
#
# Subject: ART
# Topic 1:
# design visual work schedule drawing additional studio making media technique
#
#
# Subject: ARTD
# Topic 1:
# design additional schedule industrial professional product products research studio process
#
#
# Subject: ARTE
# Topic 1:
# research education additional schedule culture visual practices teaching creative design
#
#
# Not enough data for subject: ARTF
# Subject: ARTH
# Topic 1:
# history objects visual research design study forms diverse cultural grade
#
#
# Subject: ARTJ
# Topic 1:
# japanese manga analysis history critical anime tea articles scholarly emphasis
#
#
# Subject: ARTS
# Topic 1:
# design schedule additional materials fashion studio techniques contemporary work processes
#
#
# Subject: ASRM
# Topic 1:
# actuarial science models theory advanced linear risk applications analytics insurance
#
#
# Not enough data for subject: ASST
# Subject: ASTR
# Topic 1:
# solar astronomy stars evolution planetary universe planets research physical extrasolar
#
#
# Subject: ATMS
# Topic 1:
# weather climate atmospheric data change professional sciences physical forecasts methods
#
#
# Subject: BADM
# Topic 1:
# management business data marketing professional techniques development organizations global research
#
#
# Not enough data for subject: BASQ
# Not enough data for subject: BCOG
# Not enough data for subject: BCS
# Subject: BDI
# Topic 1:
# data business communication better relevant story stakeholders practice analyses storytelling
#
#
# Subject: BIOC
# Topic 1:
# biochemistry methods thesis research recommended member prior present
#
#
# Subject: BIOE
# Topic 1:
# image bioengineering imaging biomedical project analysis systems problems engineering professional
#
#
# Not enough data for subject: BIOP
# Subject: BSE
# Topic 1:
# medical health clinical data separate elective curriculum learning research anatomy
#
#
# Subject: BTW
# Topic 1:
# composition communication report requirement campus principles professional completion skills research
#
#
# Subject: BUS
# Topic 1:
# gies work global leaders professional academic considered life understanding continue
#
#
# Not enough data for subject: CAS
# Subject: CB
# Topic 1:
# research selected area toxicology topic study seminar professional present individual
#
#
# Not enough data for subject: CDB
# Subject: CEE
# Topic 1:
# design systems analysis engineering water construction models civil theory control
#
#
# Subject: CHBE
# Topic 1:
# chemical engineering biomolecular design process processes study transfer analysis research
#
#
# Subject: CHEM
# Topic 1:
# chemistry chemical organic registration laboratory area research used spectroscopy study
#
#
# Subject: CHIN
# Topic 1:
# chinese language continuation requirement readings reading knowledge fulfills discourse
#
#
# Subject: CHLH
# Topic 1:
# health public concepts mph methods analysis community practice care experience
#
#
# Not enough data for subject: CHP
# Subject: CI
# Topic 1:
# education teaching learning instruction science research social computer admission teacher
#
#
# Not enough data for subject: CIC
# Subject: CLCV
# Topic 1:
# study literature greek ancient classical grecoroman culture rome roman classics
#
#
# Subject: CLE
# Topic 1:
# patients care clinical curriculum clerkship elective surgery management experience completion
#
#
# Subject: CMN
# Topic 1:
# communication social health media public study research theory personal marketing
#
#
# Subject: CPSC
# Topic 1:
# plant crop biology management sciences methods plants professional breeding research
#
#
# Subject: CS
# Topic 1:
# data programming design learning systems computer algorithms models software information
#
#
# Not enough data for subject: CSE
# Subject: CW
# Topic 1:
# writing creative fiction stories poetry literary work short workshop emphasis
#
#
# Subject: CWL
# Topic 1:
# literature works comparative honors cultural writing thesis study selected relation
#
#
# Not enough data for subject: CZCH
# Subject: DANC
# Topic 1:
# dance separate practice contemporary techniques physical cultural movement performance creative
#
#
# Not enough data for subject: DTX
# Subject: EALC
# Topic 1:
# chinese cultural topic poetry translation japan study culture japanese knowledge
#
#
# Subject: ECE
# Topic 1:
# systems design analysis engineering computer techniques applications electrical devices control
#
#
# Subject: ECON
# Topic 1:
# theory economic economics models analysis calculus financial monetary problems growth
#
#
# Subject: EDPR
# Topic 1:
# teaching professional requirements licensure experiences practice early council field initial
#
#
# Subject: EDUC
# Topic 1:
# education abroad social reflecting interested teaching schooling role issues implications
#
#
# Not enough data for subject: EEB
# Subject: EIL
# Topic 1:
# language teaching research writing practical test teachers second provide materials
#
#
# Subject: ENG
# Topic 1:
# engineering professional separate skills study energy schedule developing learning development
#
#
# Subject: ENGL
# Topic 1:
# literature english composition requirement completion study writing literary studies american
#
#
# Not enough data for subject: ENSU
# Not enough data for subject: ENT
# Not enough data for subject: ENVS
# Subject: EPOL
# Topic 1:
# education professional research learning diversity social educational instructional doctoral school
#
#
# Subject: EPSY
# Topic 1:
# educational research social theory learning psychology theories study evaluation development
#
#
# Subject: ERAM
# Topic 1:
# research educational philosophy analysis methods action education development inquiry addresses
#
#
# Subject: ESE
# Topic 1:
# field earth trip sustainability break supplies study current issues environment
#
#
# Subject: ESL
# Topic 1:
# placement english professional skills writing research academic test instruction sources
#
#
# Subject: ETMA
# Topic 1:
# systems management safety problems technical tsm grain special agricultural topic
#
#
# Subject: EURO
# Topic 1:
# separate union european variety relationship perspectives
#
#
# Subject: FAA
# Topic 1:
# design crip creative research music sustainable study project cripdisabled separate
#
#
# Subject: FIN
# Topic 1:
# financial finance management analysis professional investment risk data business valuation
#
#
# Not enough data for subject: FLTE
# Subject: FR
# Topic 1:
# french cultural reading language writing study speaking skills political research
#
#
# Subject: FSHN
# Topic 1:
# food nutrition science management human principles problems special application learning
#
#
# Not enough data for subject: GC
# Subject: GEOL
# Topic 1:
# geology earth research schedule additional member field groundwater evolution geochemistry
#
#
# Subject: GER
# Topic 1:
# german culture writing skills reading comprehension continuation oral listening level
#
#
# Subject: GGIS
# Topic 1:
# geospatial geography data information environmental spatial science research professional gis
#
#
# Subject: GLBL
# Topic 1:
# global research human development issues health skills rights international learning
#
#
# Subject: GRK
# Topic 1:
# greek readings prose continuation classical advanced
#
#
# Not enough data for subject: GRKM
# Not enough data for subject: GS
# Subject: GSD
# Topic 1:
# game studies design study play development covered research related normal
#
#
# Subject: GWS
# Topic 1:
# gender queer studies race sexuality womens feminist issues critical culture
#
#
# Subject: HDFS
# Topic 1:
# family development research social families children human life andor professional
#
#
# Not enough data for subject: HEBR
# Subject: HIST
# Topic 1:
# history political research social historical studies writing honors director cultural
#
#
# Not enough data for subject: HNDI
# Subject: HORT
# Topic 1:
# plant study independent urban development systems special research production plants
#
#
# Not enough data for subject: HT
# Subject: HUM
# Topic 1:
# interdisciplinary learning wright urbana street session second research lincoln later
#
#
# Subject: IB
# Topic 1:
# biology laboratory evolution ecology biological human plant field evolutionary diversity
#
#
# Subject: IE
# Topic 1:
# engineering simulation data methods models systems professional optimization theory financial
#
#
# Subject: IHLT
# Topic 1:
# health field issues interdisciplinary variety separate research experiences individuals areas
#
#
# Subject: INFO
# Topic 1:
# data design informatics research separate science makerspace field related work
#
#
# Subject: IS
# Topic 1:
# information data professional research science sciences learning design variety methods
#
#
# Subject: ITAL
# Topic 1:
# school high study special language independent continuation
#
#
# Subject: JAPN
# Topic 1:
# continuation
#
#
# Subject: JOUR
# Topic 1:
# journalism media news reporting techniques multimedia writing digital video projects
#
#
# Not enough data for subject: JS
# Subject: KIN
# Topic 1:
# physical activity activities schedule health exercise skills sport knowledge kinesiology
#
#
# Subject: KOR
# Topic 1:
# second writing continuation earned speaking year listening exam expressions achieve
#
#
# Subject: LA
# Topic 1:
# landscape design research architecture schedule additional urban professional problems areas
#
#
# Subject: LAS
# Topic 1:
# professional separate global academic experience year leadership skills study develop
#
#
# Subject: LAST
# Topic 1:
# latin american social studies policies economic quechua present life knowledge
#
#
# Subject: LAT
# Topic 1:
# latin reading prose grammar school high easy classics
#
#
# Subject: LAW
# Topic 1:
# professional legal federal problems work specialty issues listing litigation states
#
#
# Subject: LCTL
# Topic 1:
# separate intermediate advanced
#
#
# Subject: LEAD
# Topic 1:
# leadership development skills teams society theory concepts management organizations develop
#
#
# Subject: LER
# Topic 1:
# management professional human labor issues relations systems mhrir resource bargaining
#
#
# Subject: LING
# Topic 1:
# language theory linguistics research linguistic languages analysis methods computational cultural
#
#
# Subject: LLS
# Topic 1:
# studies united states latinalatino migration racial experiences immigration race research
#
#
# Subject: MACS
# Topic 1:
# media film production cinema assistant issues social political advanced positions
#
#
# Subject: MATH
# Topic 1:
# theory additional linear work functions requires substance completion equations mathematics
#
#
# Subject: MBA
# Topic 1:
# imba professional business marketing strategic expected completion firms case specialization
#
#
# Subject: MCB
# Topic 1:
# biology molecular cellular physiology research laboratory human additional tuition experimental
#
#
# Not enough data for subject: MDIA
# Not enough data for subject: MDVL
# Subject: ME
# Topic 1:
# design systems engineering control mechanical techniques analysis processes heat material
#
#
# Not enough data for subject: MICR
# Subject: MILS
# Topic 1:
# army military field trip continuation management techniques communication competencies completion
#
#
# Not enough data for subject: MIP
# Subject: MSE
# Topic 1:
# materials properties science engineering research design polymers structure behavior polymer
#
#
# Subject: MUS
# Topic 1:
# music musical study advanced performance instruction teaching techniques professional analysis
#
#
# Subject: MUSC
# Topic 1:
# music audition applied separate level schedule jazz completion instruction performance
#
#
# Subject: MUSE
# Topic 1:
# studies museums study separate supervised special selected project professional minor
#
#
# Not enough data for subject: NE
# Not enough data for subject: NEUR
# Subject: NPRE
# Topic 1:
# nuclear engineering energy design radiation power principles fuel plasma basic
#
#
# Subject: NRES
# Topic 1:
# environmental natural resources sciences management research field principles methods environment
#
#
# Subject: NS
# Topic 1:
# leadership principles marine naval warfare systems states ship navy united
#
#
# Subject: NUTR
# Topic 1:
# sciences nutritional professional current research problems discussions different biochemistry
#
#
# Subject: PATH
# Topic 1:
# veterinary pathology instruction diagnostic clinical interpretation veterinarian lesions dvm cases
#
#
# Not enough data for subject: PERS
# Subject: PHIL
# Topic 1:
# philosophy theory issues study nature social morality moral problems knowledge
#
#
# Subject: PHYS
# Topic 1:
# physics mechanics quantum theory engineering fields registration approach systems project
#
#
# Not enough data for subject: PLPA
# Not enough data for subject: POL
# Subject: PORT
# Topic 1:
# portuguese language skills instruction structures emphasis
#
#
# Subject: PS
# Topic 1:
# political science research politics policy international public issues national rights
#
#
# Subject: PSM
# Topic 1:
# learning cohort industry career internship masters professional grade current facing
#
#
# Subject: PSYC
# Topic 1:
# research psychology social theory area methods psychological study problems breadth
#
#
# Not enough data for subject: QUEC
# Subject: REES
# Topic 1:
# work supervising thesis selected research reading interdisciplinary director directed
#
#
# Not enough data for subject: REHB
# Subject: REL
# Topic 1:
# religious philosophy thought history study traditions buddhism islamic religion jewish
#
#
# Not enough data for subject: RHET
# Subject: RST
# Topic 1:
# sport recreation development management tourism concepts leisure understanding issues industry
#
#
# Subject: RUSS
# Topic 1:
# russian based reading writing practice cultural current fiction advanced postsoviet
#
#
# Not enough data for subject: SAME
# Not enough data for subject: SBC
# Subject: SCAN
# Topic 1:
# scandinavian language usually texts swedish sequence reading literature instruction immersion
#
#
# Subject: SE
# Topic 1:
# engineering design systems control analysis professional registration optimization advanced problems
#
#
# Subject: SHS
# Topic 1:
# clinical language hearing communication professional speechlanguage experience disorders study speech
#
#
# Not enough data for subject: SLAV
# Not enough data for subject: SLCL
# Subject: SOC
# Topic 1:
# social sociology research sociological methods study following poverty individual society
#
#
# Subject: SOCW
# Topic 1:
# social work practice research skills health families policy issues knowledge
#
#
# Subject: SPAN
# Topic 1:
# spanish instruction noted language unless cultural latin english level critical
#
#
# Subject: SPED
# Topic 1:
# special education disabilities curriculum study needs emphasis issues strategies individuals
#
#
# Subject: STAT
# Topic 1:
# data statistical analysis methods models statistics regression probability linear random
#
#
# Not enough data for subject: SWAH
# Subject: TAM
# Topic 1:
# mechanics analysis flow fluid theory theoretical equations applied motion fracture
#
#
# Subject: TE
# Topic 1:
# new engineering business process marketing product innovation concepts venture technology
#
#
# Subject: THEA
# Topic 1:
# theatre design stage skills techniques advanced production performance limited professional
#
#
# Subject: TRST
# Topic 1:
# translation professional interpreting language practice study theoretical theory skills competence
#
#
# Not enough data for subject: TURK
# Not enough data for subject: UKR
# Subject: UP
# Topic 1:
# planning urban development social analysis economic regional local data work
#
#
# Subject: VCM
# Topic 1:
# veterinary professional medicine systems animal equine disease health current body
#
#
# Subject: VM
# Topic 1:
# clinical curriculum teaches used animal disease laboratory provides good surgery
#
#
# Not enough data for subject: WGGP
# Not enough data for subject: WLOF
# Not enough data for subject: YDSH
# Not enough data for subject: ZULU
